# %%
import holidays
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from skforecast.plot import plot_residuals
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge
from lightgbm import LGBMRegressor
from sklearn.metrics import mean_absolute_error
from skforecast.direct import ForecasterDirectMultiVariate
from skforecast.model_selection import backtesting_forecaster_multiseries
from skforecast.model_selection import grid_search_forecaster_multiseries
from skforecast.model_selection import random_search_forecaster_multiseries
from skforecast.model_selection import bayesian_search_forecaster_multiseries
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, root_mean_squared_error, r2_score
from skforecast.model_selection._split import TimeSeriesFold

# %% [markdown]
# # Data Loading & Feature Engineering

# %%
# Load the dataset from a CSV file
df = pd.read_csv("df_time_serie_2022.csv")

# Convert the 'FECHA' column to datetime format
df.FECHA = pd.to_datetime(df.FECHA)

# Set the 'FECHA' column as the index
df.set_index("FECHA", inplace=True)

# %%
columns_with_pm10 = [col for col in df.columns if 'PM10' in col]
# Drop the columns that contain 'PM10' in their names
df.drop(columns=columns_with_pm10, inplace=True)

# %% [markdown]
# Convert the wind direction into sin and cos

# %%
columns_with_wdr = [col for col in df.columns if 'WDR' in col]
for col in columns_with_wdr:
    df[col + '_cos'] = np.cos(2 * np.pi * df[col] / 360)
    df[col + '_sin'] = np.sin(2 * np.pi * df[col] / 360)
# Drop the original WDR columns
df.drop(columns=columns_with_wdr, inplace=True)

# %% [markdown]
# Exogenous variables

# %%
# Add day of the week
df["Dia de la semana"] = df.index.dayofweek

# Add 'Mañana' if hour < 8
df["Mañana"] = 0
df.loc[df.index.hour < 8, "Mañana"] = 1

# Add 'Tarde' if 8 <= hour < 16
df["Tarde"] = 0
df.loc[(df.index.hour >= 8) & (df.index.hour < 16), "Tarde"] = 1

# Add 'Noche' if hour >= 16
df["Noche"] = 0
df.loc[df.index.hour >= 16, "Noche"] = 1

# Add holidays from Mexico
mex_holidays = holidays.MX(years=[2022, 2023, 2024])

# Add holidays from Mexico, if it is a holiday set 'Feriado' to 1
df["Feriado"] = 0
for date in mex_holidays.keys():
    df.loc[df.index.date == date, "Feriado"] = 1

# Add non-working days in Mexico
df["Dia laboral"] = 1
df.loc[(df.index.month == 1) & (df.index.day < 6), "Dia laboral"] = 0
df.loc[(df.index.month == 4) & (df.index.day > 11) & (df.index.day < 27), "Dia laboral"] = 0
df.loc[(df.index.month == 12) & (df.index.day > 19), "Dia laboral"] = 0
df.loc[(df.index.month == 7) & (df.index.day > 16), "Dia laboral"] = 0
df.loc[(df.index.month == 8) & (df.index.day < 26), "Dia laboral"] = 0

# Create exogenous variables dataframe
exog = df[["Dia de la semana", "Mes", "Dia", "Hora", "Mañana", "Tarde", "Noche", "Feriado", "Dia laboral"]]

# Drop the columns from the main dataframe
df.drop(columns=["Dia de la semana", "Mes", "Dia", "Hora", "Mañana", "Tarde", "Noche", "Feriado", "Dia laboral"], inplace=True)

# Add day of the month
exog["Dia del mes"] = exog.index.day

# Convert categorical variables to dummy variables
exog = pd.get_dummies(exog, columns=["Dia de la semana", "Mes"])

# Convert time-related features to cyclic features
exog["hour_cos"] = np.cos(2 * np.pi * exog["Hora"] / 24)
exog["hour_sin"] = np.sin(2 * np.pi * exog["Hora"] / 24)
exog["day_cos"] = np.cos(2 * np.pi * exog["Dia del mes"] / 31)
exog["day_sin"] = np.sin(2 * np.pi * exog["Dia del mes"] / 31)
exog["Dia del año cos"] = np.cos(2 * np.pi * exog["Dia"] / 365)
exog["Dia del año sin"] = np.sin(2 * np.pi * exog["Dia"] / 365)

# Drop unnecessary columns
exog.drop(columns=["Hora", "Dia del mes", "Dia"], inplace=True)

# Ensure the dataframes have hourly frequency
df = df.asfreq("h")
exog = exog.asfreq("h")

# Convert boolean columns to integers
exog = exog.astype(int)
# Out:
# C:\Users\rkale\AppData\Local\Temp\ipykernel_22684\2143946489.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exog["Dia del mes"] = exog.index.day

# %%
df.index.min(), df.index.max()
# Out:
# (Timestamp('2022-01-01 00:00:00'), Timestamp('2024-07-31 23:00:00'))

# %% [markdown]
# # Split train, test, and validation set

# %% [markdown]
# In case we already have our best hyperparameters found, we can skip the validation set and split only in train and test set

# %%
# Split data into train-validation-test
# ======================================================================================
end_train = '2024-03-10 23:00:00'

# Calculate the date to start the predictions automatically
start_pred = pd.to_datetime(end_train) + pd.Timedelta(hours=1)

data_train = df.loc[:end_train, :].copy()
data_test  = df.loc[end_train:, :].copy()
exog_train = exog.loc[:end_train, :].copy()
exog_test  = exog.loc[end_train:, :].copy()

print(f"Train dates      : {data_train.index.min()} --- {data_train.index.max()}  (n={len(data_train)})")
print(f"Test dates       : {data_test.index.min()} --- {data_test.index.max()}  (n={len(data_test)})")
# Out:
# Train dates      : 2022-01-01 00:00:00 --- 2024-03-10 23:00:00  (n=19200)
# Test dates       : 2024-03-10 23:00:00 --- 2024-07-31 23:00:00  (n=3433)

# %%
predict_time = pd.to_datetime(end_train) + pd.Timedelta(hours=1)

# %% [markdown]
# # Model training and predict

# %%
# Parameters for prediction
steps = 168
level = 'CENTRO PM2.5 (UG/M3)'
estacion = 'CENTRO PM2.5'
estacion_titulo = 'Centro'

# %%
# Create and fit forecaster MultiVariate
# ==============================================================================
# Define the regressor with the specified hyperparameters

regresor = LGBMRegressor(
    random_state=123, 
    verbose=-1, 
    n_estimators=145, 
    min_samples_leaf=1, 
    max_features='False', 
    learning_rate=0.19844611443148058, 
    num_leaves=29, 
    max_depth=12, 
    reg_alpha=0.6120379139339559, 
    reg_lambda=0.7732501918150064
)

# Initialize the forecaster with the defined regressor and other parameters
forecaster = ForecasterDirectMultiVariate(
    regressor=regresor,
    level= level,  # Change level to predict
    lags=6,
    steps=steps,
    transformer_series=StandardScaler(),
    transformer_exog=None,
    weight_func=None,
    n_jobs=1
)

# Fit the forecaster to the training data and exogenous variables
forecaster.fit(data_train, exog=exog_train)

# %%
tm = data_test.loc[predict_time:"2024-07-17 23:00:00", :]

# %%
# Use predict_interval to predict the next 48 hours and the confidence interval
forecaster.set_in_sample_residuals(series=data_train, exog=exog_train)
predictions = forecaster.predict_interval(steps=168, exog=exog_test.loc["2024-03-02 00:00:00":], last_window=tm)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 3
#       1 # Use predict_interval to predict the next 48 hours and the confidence interval
#       2 forecaster.set_in_sample_residuals(series=data_train, exog=exog_train)
# ----> 3 predictions = forecaster.predict_interval(steps=168, exog=exog_test.loc["2024-03-02 00:00:00":], last_window=tm)
#
# File c:\Users\rkale\miniconda3\envs\optimus\Lib\site-packages\skforecast\direct\_forecaster_direct_multivariate.py:2483, in ForecasterDirectMultiVariate.predict_interval(self, steps, last_window, exog, method, interval, n_boot, use_in_sample_residuals, use_binned_residuals, random_state, suppress_warnings, levels)
#    2480         check_interval(alpha=interval, alpha_literal='interval')
#    2481         nominal_coverage = interval
# -> 2483     predictions = self._predict_interval_conformal(
#    2484                       steps                   = steps,
#    2485                       last_window             = last_window,
#    2486                       exog                    = exog,
#    2487                       nominal_coverage        = nominal_coverage,
#    2488                       use_in_sample_residuals = use_in_sample_residuals,
#    2489                       use_binned_residuals    = use_binned_residuals
#    2490                   )
#    2491 else:
#    2492     raise ValueError(
#    2493         f"Invalid `method` '{method}'. Choose 'bootstrapping' or 'conformal'."
#    2494     )
#
# File c:\Users\rkale\miniconda3\envs\optimus\Lib\site-packages\skforecast\direct\_forecaster_direct_multivariate.py:2271, in ForecasterDirectMultiVariate._predict_interval_conformal(self, steps, last_window, exog, nominal_coverage, use_in_sample_residuals, use_binned_residuals)
#    2204 def _predict_interval_conformal(
#    2205     self,
#    2206     steps: int | list[int] | None = None,
#    (...)
#    2211     use_binned_residuals: bool = True
#    2212 ) -> pd.DataFrame:
#    2213     """
#    2214     Generate prediction intervals using the conformal prediction
#    2215     split method [1]_.
#    (...)
#    2263
#    2264     """
#    2266     (
#    2267         Xs,
#    2268         _,
#    2269         steps,
#    2270         prediction_index
# -> 2271     ) = self._create_predict_inputs(
#    2272             steps                   = steps,
#    2273             last_window             = last_window,
#    2274             exog                    = exog,
#    2275             predict_probabilistic   = True,
#    2276             use_in_sample_residuals = use_in_sample_residuals,
#    2277             use_binned_residuals    = use_binned_residuals
#    2278         )
#    2280     if use_in_sample_residuals:
#    2281         residuals = self.in_sample_residuals_
#
# File c:\Users\rkale\miniconda3\envs\optimus\Lib\site-packages\skforecast\direct\_forecaster_direct_multivariate.py:1730, in ForecasterDirectMultiVariate._create_predict_inputs(self, steps, last_window, exog, predict_probabilistic, use_in_sample_residuals, use_binned_residuals, check_inputs)
#    1727     last_window = self.last_window_
#    1729 if check_inputs:
# -> 1730     check_predict_input(
#    1731         forecaster_name  = type(self).__name__,
#    1732         steps            = steps,
#    1733         is_fitted        = self.is_fitted,
#    1734         exog_in_         = self.exog_in_,
#    1735         index_type_      = self.index_type_,
#    1736         index_freq_      = self.index_freq_,
#    1737         window_size      = self.window_size,
#    1738         last_window      = last_window,
#    1739         exog             = exog,
#    1740         exog_type_in_    = self.exog_type_in_,
#    1741         exog_names_in_   = self.exog_names_in_,
#    1742         interval         = None,
#    1743         max_steps        = self.steps,
#    1744         series_names_in_ = self.X_train_series_names_in_
#    1745     )
#    1747     if predict_probabilistic:
#    1748         check_residuals_input(
#    1749             forecaster_name              = type(self).__name__,
#    1750             use_in_sample_residuals      = use_in_sample_residuals,
#    (...)
#    1756             steps                        = steps
#    1757         )
#
# File c:\Users\rkale\miniconda3\envs\optimus\Lib\site-packages\skforecast\utils\utils.py:1132, in check_predict_input(forecaster_name, steps, is_fitted, exog_in_, index_type_, index_freq_, window_size, last_window, last_window_exog, exog, exog_type_in_, exog_names_in_, interval, alpha, max_steps, levels, levels_forecaster, series_names_in_, encoding)
#    1122                 warnings.warn(
#    1123                     f"To make predictions {exog_name} must start one step "
#    1124                     f"ahead of `last_window`. Missing values are filled "
#    (...)
#    1129                     MissingValuesWarning
#    1130                 )
#    1131             else:
# -> 1132                 raise ValueError(
#    1133                     f"To make predictions {exog_name} must start one step "
#    1134                     f"ahead of `last_window`.\n"
#    1135                     f"    `last_window` ends at : {last_window.index[-1]}.\n"
#    1136                     f"    {exog_name} starts at : {exog_to_check.index[0]}.\n"
#    1137                     f"     Expected index : {expected_index}."
#    1138                 )
#    1140 # Checks ForecasterSarimax
#    1141 if forecaster_name == 'ForecasterSarimax':
#    1142     # Check last_window_exog type, len, nulls and index (type and freq)
#
# ValueError: To make predictions `exog` must start one step ahead of `last_window`.
#     `last_window` ends at : 2024-07-17 23:00:00.
#     `exog` starts at : 2024-03-10 23:00:00.
#      Expected index : 2024-07-18 00:00:00.

# %% [markdown]
# # Results and evaluation of the prediction

# %%
# Calculate evaluation metrics for the predictions
# =================================================

# Get the R^2 score
r2 = r2_score(
    data_test.filter(regex=(estacion)).loc["2024-07-18 00:00:00":].head(steps), 
    predictions.pred
)

# Get the Root Mean Squared Error (RMSE)
rmse = root_mean_squared_error(
    data_test.filter(regex=(estacion)).loc["2024-07-18 00:00:00":].head(steps), 
    predictions.pred, 
    # squared=False
)

# Get the Mean Absolute Error (MAE)
mae = mean_absolute_error(
    data_test.filter(regex=(estacion)).loc["2024-07-18 00:00:00":].head(steps), 
    predictions.pred
)

# Get the Mean Absolute Percentage Error (MAPE)
mape = mean_absolute_percentage_error(
    data_test.filter(regex=(estacion)).loc["2024-07-18 00:00:00":].head(steps), 
    predictions.pred
)

# Print the evaluation metrics
print(f"R^2: {r2}")
print(f"RMSE: {rmse}")
print(f"MAE: {mae}")
print(f"MAPE: {mape}")
# Out:
# R^2: 0.27197026915431355
# RMSE: 9.292336273871896
# MAE: 7.343915319674612
# MAPE: 0.38404517786931536

# %% [markdown]
# # Plot the prediction and real data

# %%
predictions.columns
# Out:
# Index(['level', 'pred', 'lower_bound', 'upper_bound'], dtype='object')

# %%
# Create the figure and plot the real and predicted values
plt.figure(figsize=(16,8))

# Plot real data
plt.plot(data_test.filter(regex=(estacion)).loc["2024-07-18 00:00:00":].head(steps), label="Actual", color="blue", linewidth=2)

# Plot predicted values
plt.plot(predictions['pred'].head(steps), label="Prediction", color="orange", linewidth=2)

# Add the confidence interval
plt.fill_between(
    predictions.index[:steps], 
    predictions['lower_bound'].head(steps),  # Lower bound for the confidence interval
    predictions['upper_bound'].head(steps),  # Upper bound for the confidence interval
    color='orange', alpha=0.2, label="Confidence Interval"
)

# Rotate x-axis ticks for better readability
plt.xticks(rotation=85)

# Add title and labels for better context
plt.title("PM2.5 Levels Prediction for Station " + estacion_titulo + " with Confidence Intervals", fontsize=16)
plt.xlabel("Date", fontsize=14)
plt.ylabel("PM2.5 (UG/M3)", fontsize=14)

# Add grid to make it visually clear
plt.grid(True)

# Add legend to clarify the plot
plt.legend()

# Show the plot
plt.tight_layout()
plt.savefig(estacion + "_" + str(start_pred)[0:10] + ".png", dpi=400)
plt.show()

# %% [markdown]
# # Feature Importance

# %%
# Get feature importances
importances = forecaster.get_feature_importances(5)
importances.head(20)
# Out:
#                              feature  importance
# 186       CENTRO PM2.5 (UG/M3)_lag_1          57
# 1080      NORESTE 3 WSR (KMPH)_lag_1          23
# 654    SURESTE 2 PM2.5 (UG/M3)_lag_1          23
# 384        SUROESTE WSR (KMPH)_lag_1          23
# 342     SUROESTE PM2.5 (UG/M3)_lag_1          20
# 810    SURESTE 3 PM2.5 (UG/M3)_lag_1          16
# 188       CENTRO PM2.5 (UG/M3)_lag_3          15
# 1014        NORESTE 3 CO (PPM)_lag_1          15
# 420   NOROESTE 2 PM2.5 (UG/M3)_lag_1          15
# 189       CENTRO PM2.5 (UG/M3)_lag_4          15
# 108      NORESTE PM2.5 (UG/M3)_lag_1          15
# 501        NORTE PM2.5 (UG/M3)_lag_4          14
# 462      NOROESTE 2 WSR (KMPH)_lag_1          13
# 389        SUROESTE WSR (KMPH)_lag_6          13
# 618       NORESTE 2 WSR (KMPH)_lag_1          12
# 390        NOROESTE 2 CO (PPM)_lag_1          12
# 863               SUR CO (PPM)_lag_6          12
# 1056          NORESTE 3 RH (%)_lag_1          12
# 498        NORTE PM2.5 (UG/M3)_lag_1          11
# 876              SUR NOX (PPB)_lag_1          11

# %%
importances.head(20).to_csv("importances_" + estacion_titulo + ".csv")

# %%
from skforecast.model_selection import TimeSeriesFold

# %%
cv = TimeSeriesFold(
         steps                 = 168,
         initial_train_size    = len(df.loc[:end_train]),
         refit                 = False,
         fixed_train_size      = False,
         gap                   = 0,
         skip_folds            = None,
         allow_incomplete_fold = True
     )

metric, predictions = backtesting_forecaster_multiseries(
                          forecaster = forecaster,
                          series      = df.filter(regex=(estacion)),
                          exog       = exog,
                          cv         = cv,
                          metric     = ['mean_squared_error',"mean_absolute_percentage_error","root_mean_squared_scaled_error"]
                      )
